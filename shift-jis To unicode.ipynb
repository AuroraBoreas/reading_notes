# %% [markdown]
# Sub Button1_Click()  'Button_AllClearに移行したため削除可
# '    Range("D15:F19").Select
# '    Selection.ClearContents
# '    Range("AA15:AI19").Select
# '    Selection.ClearContents
# '    Range("B13").Select
# '    Selection.ClearContents
# '    Range("B22:AL66").Select
# '    Selection.Clear
# '
# '    ThisWorkbook.Worksheets("Spectrum").Activate
# '    Range("B2:AE402").Select
# '    Selection.ClearContents
# '
# '    ThisWorkbook.Sheets("Report").Activate
# '    Range("A4:K67").Select
# '    Selection.Clear
# '
# '    ThisWorkbook.Sheets("Lv_xy").Activate
# '    Range("B2").Select
# End Sub
#
# Sub Button15_Click()    'Button_Reportに移行したため削除可
# '
# '    Sheets("Report").Select
# '    Range("c4:K67").Select
# '    Selection.Clear
# '    Sheets("Lv_xy").Select
# '    Range("A3:J66").Select
# '    Selection.Copy
# '    Sheets("Report").Select
# '    Range("B4").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '    Selection.PasteSpecial Paste:=xlPasteFormats, Operation:=xlNone, _
# '        SkipBlanks:=False, Transpose:=False
# End Sub
#
#
#
# '    Private Sub ComboBox1_Change()
#
# 'Dim Rx As Double, Ry As Double
# 'Dim Gx As Double, Gy As Double
# 'Dim Bx As Double, By As Double
# 'Dim Wx As Double, Wy As Double
# '
# '
# 'If ComboBox1.Text = "2007 40X" Then
# '    Rx = 0.652: Ry = 0.323
# '    Gx = 0.215: Gy = 0.665
# '    Bx = 0.149: By = 0.065
# '    Wx = 0.274: Wy = 0.274
# 'ElseIf ComboBox1.Text = "2007 46X" Then
# '    Rx = 0.652: Ry = 0.324
# '    Gx = 0.213: Gy = 0.662
# '    Bx = 0.147: By = 0.063
# '    Wx = 0.274: Wy = 0.274
# 'ElseIf ComboBox1.Text = "2007 52X" Then
# '    Rx = 0.647: Ry = 0.324
# '    Gx = 0.215: Gy = 0.667
# '    Bx = 0.148: By = 0.069
# '    Wx = 0.274: Wy = 0.274
# 'ElseIf ComboBox1.Text = "2007 40W" Then
# '    Rx = 0.65: Ry = 0.324
# '    Gx = 0.216: Gy = 0.664
# '    Bx = 0.148: By = 0.064
# '    Wx = 0.274: Wy = 0.274
# 'ElseIf ComboBox1.Text = "2007 46W" Then
# '    Rx = 0.651: Ry = 0.324
# '    Gx = 0.211: Gy = 0.662
# '    Bx = 0.148: By = 0.059
# '    Wx = 0.274: Wy = 0.274
# 'ElseIf ComboBox1.Text = "2007 52W" Then
# '    Rx = 0.658: Ry = 0.327
# '    Gx = 0.203: Gy = 0.669
# '    Bx = 0.146: By = 0.066
# '    Wx = 0.274: Wy = 0.274
# 'ElseIf ComboBox1.Text = "2007 70LED" Then
# '    Rx = 0.695: Ry = 0.292
# '    Gx = 0.186: Gy = 0.692
# '    Bx = 0.144: By = 0.065
# '    Wx = 0.272: Wy = 0.274
# 'ElseIf ComboBox1.Text = "2008 52VM(sLCD)" Then          '2008/10/2追加
# '    Rx = 0.6512: Ry = 0.3304
# '    Gx = 0.2115: Gy = 0.676
# '    Bx = 0.1502: By = 0.0555
# '    Wx = 0.3139: Wy = 0.3275
# 'ElseIf ComboBox1.Text = "2008 Wasabi(WLED)" Then
# '    Rx = 0.6653: Ry = 0.3198
# '    Gx = 0.2446: Gy = 0.6314
# '    Bx = 0.1449: By = 0.0509
# '    Wx = 0.2764: Wy = 0.2821
# 'ElseIf ComboBox1.Text = "2007 Samsung950 Movie" Then          '2008/10/8　追加
# '    Rx = 0.6464: Ry = 0.33
# '    Gx = 0.2921: Gy = 0.591
# '    Bx = 0.1508: By = 0.0603
# '    Wx = 0.2677: Wy = 0.2714
# 'ElseIf ComboBox1.Text = "2007 Samsung950 Movie" Then          '2008/10/8　追加
# '    Rx = 0.6464: Ry = 0.33
# '    Gx = 0.2921: Gy = 0.591
# '    Bx = 0.1508: By = 0.0603
# '    Wx = 0.2677: Wy = 0.2714
# 'ElseIf ComboBox1.Text = "2007 Samsung950 Dynamic" Then          '2008/10/9　追加
# '    Rx = 0.6488: Ry = 0.3284
# '    Gx = 0.2808: Gy = 0.6388
# '    Bx = 0.1494: By = 0.0542
# '    Wx = 0.2707: Wy = 0.2743
# 'Else
# '    MsgBox ("準備されていないデータを選択しています")
# 'End If
# '
# 'Cells(15, 12) = Rx: Cells(15, 13) = Ry
# 'Cells(16, 12) = Gx: Cells(16, 13) = Gy
# 'Cells(17, 12) = Bx: Cells(17, 13) = By
# 'Cells(19, 12) = Wx: Cells(19, 13) = Wy
#
#
#
# 'End Sub
#
# '更新履歴
# 'V0.90 2007/9/6
# '   β版作成、”組”だけに配布
# 'V0.91 2007/9/10
# '   重心点が三角形の外に出てしまうバグを修正
# '   重心点とx,y座標が同じ点が頂点にカウントされないバグを修正
# '   Excel重心点をExcel内で計算ではなく、マクロで計算したものをExcelに代入するように変更
# 'V0.92 2007/9/11
# '   グラフの軸設定追加
# '   既知データのComboBOX追加
# 'V0.93  2007/9/12
# '   色域の単純比較比の表示追加
# 'V0.94  2016/1/25 (SSV Hiroaki Suzuki)
# 'Object(Button) Name and other charactor were changed from Japanese to English because SSV didn't use in Chinase OS
# '
# '============================================================================================
# '
# '          素人が書いてますので、バグでない、アホなコードに関してはご容赦下さい。。。
# '
# '=============================================================================================
# '
#
#
# Sub calc_area(ByVal data_no As Integer)
#
# '交点算出
# Dim OrgRx As Double, OrgRy As Double    'sRGB等の基準色域のx,y値(u',v'値)
# Dim OrgGx As Double, OrgGy As Double
# Dim OrgBx As Double, OrgBy As Double
# Dim SetRx As Double, SetRy As Double    'セットの色域のx,y値(u',v'値)
# Dim SetGx As Double, SetGy As Double
# Dim SetBx As Double, SetBy As Double
# Dim a As Double, b As Double            'R,G,Bを結んだそれぞれの直線式のa,b
# Dim aRGorg As Double, bRGorg As Double  '基準色域のR,G,Bを結んだそれぞれの直線式のa,b
# Dim aGBorg As Double, bGBorg As Double
# Dim aBRorg As Double, bBRorg As Double
# Dim aRGset As Double, bRGset As Double  'セット色域のR,G,Bを結んだそれぞれの直線式のa,b
# Dim aGBset As Double, bGBset As Double
# Dim aBRset As Double, bBRset As Double
# Dim xTmp As Double, yTmp As Double
# Dim Judge As Boolean                    '直線の交点が有効な交点かどうかのJudge結果
# Dim x() As Double, y() As Double        '求まった交点の座標を入れるアレイ
# Dim Centx As Double, Centy As Double    '交点重心点のxy座標
#
# Dim i As Integer, j As Integer
# Dim intVertex As Integer                '頂点の数を数える
#
# Dim blnuv As Boolean                    'u'v'座標系の場合にTrue、xy座標系はFalse
#
# 'If Optuv = True Then
#     blnuv = True
# 'Else
# '    blnuv = False
# 'End If
#
# ''Excelのセルリセット
# 'Cells(37, 3) = "": Cells(37, 4) = ""
# 'Cells(38, 3) = "": Cells(38, 4) = ""
# 'Cells(39, 3) = "": Cells(39, 4) = ""
# 'Cells(40, 3) = "": Cells(40, 4) = ""
# 'Cells(41, 3) = "": Cells(41, 4) = ""
# 'Cells(42, 3) = "": Cells(42, 4) = ""
# 'Cells(43, 3) = "": Cells(43, 4) = ""
# 'Cells(44, 3) = "": Cells(44, 4) = ""
#
#
# intVertex = 0
# 'u'v'座標系の場合のデータ取得
# If blnuv = True Then
#     OrgRx = Cells(7, 24): OrgRy = Cells(7, 25)
#     OrgGx = Cells(8, 24): OrgGy = Cells(8, 25)
#     OrgBx = Cells(9, 24): OrgBy = Cells(9, 25)
#
#     SetRx = Cells(16 + data_no, 18): SetRy = Cells(16 + data_no, 19)
#     SetGx = Cells(17 + data_no, 18): SetGy = Cells(17 + data_no, 19)
#     SetBx = Cells(18 + data_no, 18): SetBy = Cells(18 + data_no, 19)
# End If
# 'xy座標系の場合のデータ取得
# 'If blnuv = False Then
# '    OrgRx = Cells(5, 12): OrgRy = Cells(5, 13)
# '    OrgGx = Cells(6, 12): OrgGy = Cells(6, 13)
# '    OrgBx = Cells(7, 12): OrgBy = Cells(7, 13)
# '
# '    SetRx = Cells(15, 12): SetRy = Cells(15, 13)
# '    SetGx = Cells(16, 12): SetGy = Cells(16, 13)
# '    SetBx = Cells(17, 12): SetBy = Cells(17, 13)
# 'End If
#
# 'グラフの参照先変更
# 'If blnuv = True Then
# '    ActiveSheet.ChartObjects("グラフ 1").Activate
# '    ActiveChart.PlotArea.Select
# '    '基準グラフ
# '    ActiveChart.SeriesCollection(1).XValues = "=Sheet1!R5C15:R8C15"
# '    ActiveChart.SeriesCollection(1).Values = "=Sheet1!R5C16:R8C16"
# '    'セット色度点グラフ
# '    ActiveChart.SeriesCollection(2).XValues = "=Sheet1!R15C15:R18C15"
# '    ActiveChart.SeriesCollection(2).Values = "=Sheet1!R15C16:R18C16"
# 'ElseIf blnuv = False Then
# '    ActiveSheet.ChartObjects("グラフ 1").Activate
# '    ActiveChart.PlotArea.Select
# '    '基準グラフ
# '    ActiveChart.SeriesCollection(1).XValues = "=Sheet1!R5C12:R8C12"
# '    ActiveChart.SeriesCollection(1).Values = "=Sheet1!R5C13:R8C13"
# '    'セット色度点グラフ
# '    ActiveChart.SeriesCollection(2).XValues = "=Sheet1!R15C12:R18C12"
# '    ActiveChart.SeriesCollection(2).Values = "=Sheet1!R15C13:R18C13"
# 'End If
#
#
# '基準色域の3角形の直線式算出
# Call makeFormula(OrgRx, OrgRy, OrgGx, OrgGy, a, b)
#     aRGorg = a: bRGorg = b
# Call makeFormula(OrgGx, OrgGy, OrgBx, OrgBy, a, b)
#     aGBorg = a: bGBorg = b
# Call makeFormula(OrgBx, OrgBy, OrgRx, OrgRy, a, b)
#     aBRorg = a: bBRorg = b
#
# 'セット側の3角形の直線式算出
# Call makeFormula(SetRx, SetRy, SetGx, SetGy, a, b)
#     aRGset = a: bRGset = b
# Call makeFormula(SetGx, SetGy, SetBx, SetBy, a, b)
#     aGBset = a: bGBset = b
# Call makeFormula(SetBx, SetBy, SetRx, SetRy, a, b)
#     aBRset = a: bBRset = b
#
# '基準側RGのラインとセット側の3角形の直線とのそれぞれの交点算出
# '対RGライン
# Call GetCrossPoint(aRGorg, bRGorg, aRGset, bRGset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgRx, OrgRy, OrgGx, OrgGy, SetRx, SetRy, SetGx, SetGy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# '対GBライン
# Call GetCrossPoint(aRGorg, bRGorg, aGBset, bGBset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgRx, OrgRy, OrgGx, OrgGy, SetGx, SetGy, SetBx, SetBy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# '対BRライン
# Call GetCrossPoint(aRGorg, bRGorg, aBRset, bBRset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgRx, OrgRy, OrgGx, OrgGy, SetBx, SetBy, SetRx, SetRy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# '基準側GBのラインとセット側の3角形の直線とのそれぞれの交点算出
# '対RGライン
# Call GetCrossPoint(aGBorg, bGBorg, aRGset, bRGset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgGx, OrgGy, OrgBx, OrgBy, SetRx, SetRy, SetGx, SetGy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# '対GBライン
# Call GetCrossPoint(aGBorg, bGBorg, aGBset, bGBset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgGx, OrgGy, OrgBx, OrgBy, SetGx, SetGy, SetBx, SetBy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# '対BRライン
# Call GetCrossPoint(aGBorg, bGBorg, aBRset, bBRset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgGx, OrgGy, OrgBx, OrgBy, SetBx, SetBy, SetRx, SetRy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# '基準側brのラインとセット側の3角形の直線とのそれぞれの交点算出
# '対RGライン
# Call GetCrossPoint(aBRorg, bBRorg, aRGset, bRGset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgBx, OrgBy, OrgRx, OrgRy, SetRx, SetRy, SetGx, SetGy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# '対GBライン
# Call GetCrossPoint(aBRorg, bBRorg, aGBset, bGBset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgBx, OrgBy, OrgRx, OrgRy, SetGx, SetGy, SetBx, SetBy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# '対BRライン
# Call GetCrossPoint(aBRorg, bBRorg, aBRset, bBRset, xTmp, yTmp)
# Call JudgeCrossPoint(OrgBx, OrgBy, OrgRx, OrgRy, SetBx, SetBy, SetRx, SetRy, xTmp, yTmp, Judge)
# Call CopyCrossPoint(xTmp, yTmp, Judge, intVertex, ByVal data_no)
# Dim InsideJugde As Boolean
#
# '==========色度点の頂点がもう一方の色度域の内側に入っているかを確認して、追加
# 'InsideCheck(上側にあたるラインのa, 同b, 下側に当たるラインのa, 同b, Checkするx, 同y, 結果)
# 'InsideCheck2(上側にあたるラインのa, 同b, 上側に当たるラインのa, 同b, Checkするx, 同y, 結果)　両方上側になる
# 'InsideCheck2(下側にあたるラインのa, 同b, 下側に当たるラインのa, 同b, Checkするx, 同y, 結果)　両方下側になる
# 'OrgBGラインとOrgBRラインの内側にSetBが入っているか
# Call InsideCheck(aGBorg, bGBorg, aBRorg, bBRorg, SetBx, SetBy, InsideJudge)
# Call CopyCrossPoint(SetBx, SetBy, InsideJudge, intVertex, ByVal data_no)
# 'SetBGラインとSetBRラインの内側にOrgBが入っているか
# Call InsideCheck(aGBset, bGBset, aBRset, bBRset, OrgBx, OrgBy, InsideJudge)
# Call CopyCrossPoint(OrgBx, OrgBy, InsideJudge, intVertex, ByVal data_no)
# 'OrgGBラインとOrgGRラインの内側にSetGが入っているか
# Call InsideCheck2(aGBorg, bGBorg, aRGorg, bRGorg, SetGx, SetGy, InsideJudge)
# Call CopyCrossPoint(SetGx, SetGy, InsideJudge, intVertex, ByVal data_no)
# 'SetGBラインとSetGRラインの内側にOrgGが入っているか
# Call InsideCheck2(aGBset, bGBset, aRGset, bRGset, OrgGx, OrgGy, InsideJudge)
# Call CopyCrossPoint(OrgGx, OrgGy, InsideJudge, intVertex, ByVal data_no)
# 'OrgGBラインとOrgGRラインの内側にSetGが入っているか
# Call InsideCheck3(aRGorg, bRGorg, aBRorg, bBRorg, SetRx, SetRy, InsideJudge)
# Call CopyCrossPoint(SetRx, SetRy, InsideJudge, intVertex, ByVal data_no)
# 'SetGBラインとSetGRラインの内側にOrgGが入っているか
# Call InsideCheck3(aRGset, bRGset, aBRset, bBRset, OrgRx, OrgRy, InsideJudge)
# Call CopyCrossPoint(OrgRx, OrgRy, InsideJudge, intVertex, ByVal data_no)
#
#
# ReDim x(1 To intVertex) As Double
# ReDim y(1 To intVertex) As Double
#
# Centx = 0: Centy = 0
#
# For i = 1 To intVertex
#     x(i) = Cells(14 + data_no + i, 28)
#     y(i) = Cells(14 + data_no + i, 29)
#     Centx = Centx + x(i)
#     Centy = Centy + y(i)
# Next i
#     Centx = Centx / intVertex
#     Centy = Centy / intVertex
#
#
# '========それぞれの点が、重心点から垂直指針基準で、どれだけの角度を持っているか、計算
# 'Dim l As Double
# Dim Area As Integer                             '第何象限に入っているか
# Dim CheckDone() As Boolean
# Dim intOrder() As Integer
# 'Dim OrderCounter As Integer
# Dim intQuadrant() As Integer                    'それぞれの点が第何象限に入っているか
# Dim dblAngle() As Double
# Dim minAngle As Double                          '計算途中の最小角度
# Dim minNumber As Integer                        '計算途中の最小になった番号
#
# ReDim CheckDone(1 To intVertex) As Boolean      'intOrderに値を入れたものをチェックする為
# ReDim intOrder(1 To intVertex) As Integer       '右回りになる順番を入れるアレイ
# ReDim intQuadrant(1 To intVertex) As Integer
# ReDim dblAngle(1 To intVertex) As Double
#
#
# 'Dim intArea1 As Integer, intArea2 As Integer, intArea3 As Integer, intArea4 As Integer
# 'それぞれの点が第1から第4のどの象限に入っているか確認する。
# For i = 1 To intVertex
#     Call AreaCheck(Centx, Centy, x(i), y(i), Area)
#     intQuadrant(i) = Area
# Next i
#
#
# For i = 1 To intVertex
#     Call CalcAngle(Centx, Centy, x(i), y(i), dblAngle(i))
#     If intQuadrant(i) = 2 Then
#         dblAngle(i) = 180 - dblAngle(i)
#     ElseIf intQuadrant(i) = 3 Then
#         dblAngle(i) = 180 + dblAngle(i)
#     ElseIf intQuadrant(i) = 4 Then
#         dblAngle(i) = 360 - dblAngle(i)
#     End If
#
# Next i
#
# For i = 1 To intVertex
#     CheckDone(i) = False
# Next i
#
# '角度の小さい順に順位をつける
# For j = 1 To intVertex
#     minAngle = 360
#     For i = 1 To intVertex
#         If CheckDone(i) = False Then
#             If dblAngle(i) <= minAngle Then
#                 minAngle = dblAngle(i)
#                 minNumber = i
#             End If
#         End If
#     Next i
#     intOrder(minNumber) = j
#     CheckDone(minNumber) = True
# Next j
#
# '=========順番を入れ替えてCopy⇒Paste
# '値と色のリセット
# For i = 1 To 8
#     Cells(14 + data_no + i, 32).Interior.ColorIndex = 0
#     Cells(14 + data_no + i, 33).Interior.ColorIndex = 0
#     Cells(14 + data_no + i, 34).Interior.ColorIndex = 0
#     Cells(14 + data_no + i, 32) = ""
#     Cells(14 + data_no + i, 33) = ""
#     Cells(14 + data_no + i, 34) = ""
# Next i
# '値の入力
# For i = 1 To intVertex
#     Cells(14 + data_no + intOrder(i), 32) = dblAngle(i)
#     Cells(14 + data_no + intOrder(i), 33) = x(i)
#     Cells(14 + data_no + intOrder(i), 34) = y(i)
#     If i = 1 Then
#         Cells(14 + data_no + intOrder(i), 32).Interior.ColorIndex = 6
#         Cells(14 + data_no + intOrder(i), 33).Interior.ColorIndex = 6
#         Cells(14 + data_no + intOrder(i), 34).Interior.ColorIndex = 6
#     End If
#     If i = 2 Then
#         Cells(14 + data_no + intOrder(i), 32).Interior.ColorIndex = 8
#         Cells(14 + data_no + intOrder(i), 33).Interior.ColorIndex = 8
#         Cells(14 + data_no + intOrder(i), 34).Interior.ColorIndex = 8
#     End If
#     If i = 3 Then
#         Cells(14 + data_no + intOrder(i), 32).Interior.ColorIndex = 4
#         Cells(14 + data_no + intOrder(i), 33).Interior.ColorIndex = 4
#         Cells(14 + data_no + intOrder(i), 34).Interior.ColorIndex = 4
#     End If
#     If i = 4 Then
#         Cells(14 + data_no + intOrder(i), 32).Interior.ColorIndex = 41
#         Cells(14 + data_no + intOrder(i), 33).Interior.ColorIndex = 41
#         Cells(14 + data_no + intOrder(i), 34).Interior.ColorIndex = 41
#     End If
#     If i = 5 Then
#         Cells(14 + data_no + intOrder(i), 32).Interior.ColorIndex = 22
#         Cells(14 + data_no + intOrder(i), 33).Interior.ColorIndex = 22
#         Cells(14 + data_no + intOrder(i), 34).Interior.ColorIndex = 22
#     End If
#     If i = 6 Then
#         Cells(14 + data_no + intOrder(i), 32).Interior.ColorIndex = 39
#         Cells(14 + data_no + intOrder(i), 33).Interior.ColorIndex = 39
#         Cells(14 + data_no + intOrder(i), 34).Interior.ColorIndex = 39
#     End If
#     If i = 7 Then
#         Cells(14 + data_no + intOrder(i), 32).Interior.ColorIndex = 6
#         Cells(14 + data_no + intOrder(i), 33).Interior.ColorIndex = 6
#         Cells(14 + data_no + intOrder(i), 34).Interior.ColorIndex = 6
#     End If
#     If i = 8 Then
#         Cells(14 + data_no + intOrder(i), 32).Interior.ColorIndex = 6
#         Cells(14 + data_no + intOrder(i), 33).Interior.ColorIndex = 6
#         Cells(14 + data_no + intOrder(i), 34).Interior.ColorIndex = 6
#     End If
# Next i
#     Cells(14 + data_no + intVertex + 1, 28) = Cells(37, 33)
#     Cells(14 + data_no + intVertex + 1, 29) = Cells(37, 34)
#
#
# 'グラフ描写
# '    ActiveSheet.ChartObjects("グラフ 1").Activate
# '    ActiveChart.PlotArea.Select
# 'If intVertex = 3 Then
# '    ActiveChart.SeriesCollection(12).XValues = "=Sheet1!R37C8:R40C8"
# '    ActiveChart.SeriesCollection(12).Values = "=Sheet1!R37C9:R40C9"
# 'End If
# 'If intVertex = 4 Then
# '    ActiveChart.SeriesCollection(12).XValues = "=Sheet1!R37C8:R41C8"
# '    ActiveChart.SeriesCollection(12).Values = "=Sheet1!R37C9:R41C9"
# 'End If
# 'If intVertex = 5 Then
# '    ActiveChart.SeriesCollection(12).XValues = "=Sheet1!R37C8:R42C8"
# '    ActiveChart.SeriesCollection(12).Values = "=Sheet1!R37C9:R42C9"
# 'End If
# 'If intVertex = 6 Then
# '    ActiveChart.SeriesCollection(12).XValues = "=Sheet1!R37C8:R43C8"
# '    ActiveChart.SeriesCollection(12).Values = "=Sheet1!R37C9:R43C9"
# 'End If
# 'If intVertex = 7 Then
# '    ActiveChart.SeriesCollection(12).XValues = "=Sheet1!R37C8:R44C8"
# '    ActiveChart.SeriesCollection(12).Values = "=Sheet1!R37C9:R44C9"
# 'End If
#
# '=========================================
# Dim dblSize As Double                           '多角形の面積
# Dim TriangleSize As Double                      '比較する基準の3角形の面積
# Dim SetTriangleSize As Double                   'セット側の色域の3角形面積
#
# 'Cells(45, 32) = Centx
# 'Cells(45, 33) = Centy
#
#
# '順番に並べなおした状態で値を入れなおす
# For i = 1 To intVertex
#     x(i) = Cells(14 + data_no + i, 33)
#     y(i) = Cells(14 + data_no + i, 34)
# Next i
#
# dblSize = 0: TriangleSize = 0
#
# For i = 1 To intVertex
#     j = i + 1
#     If j > intVertex Then
#         j = 1
#     End If
#     dblSize = dblSize + Abs(Area3Angle_xy(Centx, x(i), x(j), Centy, y(i), y(j)))
# Next i
#
#
# TriangleSize = Abs(Area3Angle_xy(Centx, OrgRx, OrgGx, Centy, OrgRy, OrgGy)) + _
#                               Abs(Area3Angle_xy(Centx, OrgGx, OrgBx, Centy, OrgGy, OrgBy)) + _
#                               Abs(Area3Angle_xy(Centx, OrgBx, OrgRx, Centy, OrgBy, OrgRy))
# SetTriangleSize = Abs(Area3Angle_xy(SetRx, SetGx, SetBx, SetRy, SetGy, SetBy))
#
# '=========================================================================
# '=========================================================================
# 'デバッグ用　ヘロンの公式を使用した面積計算
# 'Dim dbgAx As Double, dbgAy As Double
# 'Dim dbgBx As Double, dbgBy As Double
# 'Dim dbgCx As Double, dbgCy As Double
# 'Dim dbgDx As Double, dbgDy As Double
# 'Dim dbgEx As Double, dbgEy As Double
# 'Dim dbgFx As Double, dbgFy As Double
# 'Dim ABLen As Double, BCLen As Double, CALen As Double
# 'Dim DBLen As Double, ADLen As Double
# 'Dim AELen As Double, DELen As Double
# 'Dim BFLen As Double, DFLen As Double
# 'Dim dbgArea1 As Double, dbgArea2 As Double, dbgArea3 As Double
# 'Dim dbgArea4 As Double, dbgArea5 As Double, dbgArea6 As Double
# 'Dim dbgAreaTotal As Double
# '
# ''FIX2 40Xのデータを使用してエースさん手計算との比較
# 'dbgAx = 0.158086956521739: dbgAy = 0.147608695652173    '水色点
# 'dbgBx = 0.294703940362087: dbgBy = 0.13973482428115    '青色点
# 'dbgCx = 0.150534176646226: dbgCy = 0.065786913667448    '黄緑点
# 'dbgDx = 0.616350000000002: dbgDy = 0.350899999999999    '黄色点
# 'dbgEx = SetGx: dbgEy = SetGy        'Green
# 'dbgFx = OrgRx: dbgFy = OrgRy        'Red
# '
# 'ABLen = CalcLength(dbgAx, dbgAy, dbgBx, dbgBy)
# 'BCLen = CalcLength(dbgBx, dbgBy, dbgCx, dbgCy)
# 'CALen = CalcLength(dbgCx, dbgCy, dbgAx, dbgAy)
# 'DBLen = CalcLength(dbgDx, dbgDy, dbgBx, dbgBy)
# 'ADLen = CalcLength(dbgAx, dbgAy, dbgDx, dbgDy)
# 'AELen = CalcLength(dbgAx, dbgAy, dbgEx, dbgEy)
# 'DELen = CalcLength(dbgDx, dbgDy, dbgEx, dbgEy)
# 'BFLen = CalcLength(dbgBx, dbgBy, dbgFx, dbgFy)
# 'DFLen = CalcLength(dbgDx, dbgDy, dbgFx, dbgFy)
# '
# 'dbgArea1 = Area3Angle_3sd(ABLen, BCLen, CALen)
# 'dbgArea2 = Area3Angle_3sd(ABLen, DBLen, ADLen)
# 'dbgArea3 = Area3Angle_3sd(ADLen, AELen, DELen)
# 'dbgArea4 = Area3Angle_3sd(DBLen, BFLen, DFLen)
# '
# 'dbg2Area1 = Abs(Area3Angle_xy(dbgAx, dbgBx, dbgCx, dbgAy, dbgBy, dbgCy))
# 'dbg2Area2 = Abs(Area3Angle_xy(dbgAx, dbgBx, dbgDx, dbgAy, dbgBy, dbgDy))
# 'dbg2Area3 = Abs(Area3Angle_xy(dbgAx, dbgEx, dbgDx, dbgAy, dbgEy, dbgDy))
# 'dbg2Area4 = Abs(Area3Angle_xy(dbgBx, dbgDx, dbgFx, dbgBy, dbgDy, dbgFy))
# '
# 'dbgAreaTotal = dbgArea1 + dbgArea2 + dbgArea3 + dbgArea4
# 'dbgarea2total = dbg2Area1 + dbg2Area2 + dbg2Area3 + dbg2Area4
# '
# 'デバッグ用終了
# '========================================================================
# '========================================================================
#
# 'If blnuv = False Then
# '    Cells(14, 3) = "x"
# '    Cells(14, 4) = "y"
# '    Cells(14, 32) = "x"
# '    Cells(14, 33) = "y"
# 'ElseIf blnuv = True Then
# '    Cells(14, 3) = "u'"
# '    Cells(14, 4) = "v'"
# '    Cells(14, 32) = "u'"
# '    Cells(14, 33) = "v'"
# 'End If
#
# If blnuv = True Then
#    'Cells(34, 11) = Cells(4, 11) & "比 " & "u'v'座標系での"
#     'cells(14, 11) = Cells(4, 11) & "比 " & "u'v'座標系での色域面積"
#     'Cells(39, 11) = Cells(4, 11) & " 比 " & "u'v'座標系でのカバー率"
# '    ActiveSheet.Shapes("AutoShape 25").Select
#     Range("J26").Select
# '    ActiveSheet.ChartObjects("グラフ 1").Activate
# '    ActiveChart.Axes(xlCategory).Select
# '    With ActiveChart.Axes(xlCategory)
# '        .MinimumScale = 0
# '        .MaximumScale = 0.7
# '        .MinorUnit = 0.01
# '        .MajorUnit = 0.1
# '        .Crosses = xlAutomatic
# '        .ReversePlotOrder = False
# '        .ScaleType = xlLinear
# '        .DisplayUnit = xlNone
# '    End With
# '    ActiveChart.Axes(xlValue).Select
# '    With ActiveChart.Axes(xlValue)
# '        .MinimumScale = 0
# '        .MaximumScale = 0.7
# '        .MinorUnit = 0.01
# '        .MajorUnit = 0.1
# '        .Crosses = xlAutomatic
# '        .ReversePlotOrder = False
# '        .ScaleType = xlLinear
# '        .DisplayUnit = xlNone
# '    End With
# ElseIf blnuv = False Then
#     'Cells(34, 11) = Cells(4, 11) & "比 " & "xy 座標系での"
#     'cells(14, 11) = Cells(4, 11) & "比 " & "xy 座標系での色域面積"
#     'Cells(39, 11) = Cells(4, 11) & " 比 " & "xy  座標系でのカバー率"
#     ActiveSheet.ChartObjects("グラフ 1").Activate
#     ActiveChart.Axes(xlCategory).Select
#     With ActiveChart.Axes(xlCategory)
#         .MinimumScale = 0
#         .MaximumScale = 0.8
#         .MinorUnit = 0.0147
#         .MajorUnit = 0.1
#         .Crosses = xlAutomatic
#         .ReversePlotOrder = False
#         .ScaleType = xlLinear
#         .DisplayUnit = xlNone
#     End With
#     ActiveChart.Axes(xlValue).Select
#     With ActiveChart.Axes(xlValue)
#         .MinimumScale = 0
#         .MaximumScale = 0.8
#         .MinorUnit = 0.01
#         .MajorUnit = 0.1
#         .Crosses = xlAutomatic
#         .ReversePlotOrder = False
#         .ScaleType = xlLinear
#         .DisplayUnit = xlNone
#     End With
# End If
#
# Cells(18 + data_no, 35) = dblSize / TriangleSize
# Cells(19 + data_no, 35) = SetTriangleSize / TriangleSize
#
#
# 'debugRatio = dbgarea2total / TriangleSize
#
# End Sub
#
# Private Function CalcLength(x1, y1, x2, y2)
#
# CalcLength = Sqr((x1 - x2) ^ 2 + (y1 - y2) ^ 2)
#
#
# End Function
#
#
# Private Function CalcAngle(Centx, Centy, x, y, dblAngle)
#
# Dim Tempx As Double
# Dim Tempy As Double
#
# Tempx = Abs(x - Centx)
# Tempy = Abs(y - Centy)
#
# '0で除算しないように、0の場合は、0.000000001にする
# If Tempy = 0 Then
#     Tempy = 0.000000001
# End If
#
# dblAngle = Atn(Tempx / Tempy) * (180 / 3.14159265358979)
#
#
# End Function
#
# Private Function InsideCheck3(a1, b1, a2, b2, x, y, InsideJudge)
#
# InsideJudge = False
# If a1 < 0 And a2 >= 0 Then
#     If y <= a1 * x + b1 Then
#         If y >= a2 * x + b2 Then
#             InsideJudge = True
#         Else
#             InsideJudge = False
#         End If
#     End If
# ElseIf a1 < 0 And a2 >= 0 Then
#     If y <= a1 * x + b1 Then
#         If y >= a2 * x + b2 Then
#             InsideJudge = True
#         Else
#             InsideJudge = False
#         End If
#     End If
# Else
#     MsgBox ("用意されていない組み合わせです、ソフト修正が必要です。")
# End If
#
#
# End Function
# Private Function InsideCheck2(a1, b1, a2, b2, x, y, InsideJudge)
#
# InsideJudge = False
# If a1 >= 0 And a2 < 0 Then
#     If y <= a1 * x + b1 Then
#         If y <= a2 * x + b2 Then
#             InsideJudge = True
#         Else
#             InsideJudge = False
#         End If
#     End If
# ElseIf a1 < 0 And a2 < 0 Then
#     If y >= a1 * x + b1 Then
#         If y <= a2 * x + b2 Then
#             InsideJudge = True
#         Else
#             InsideJudge = False
#         End If
#     End If
# Else
#     MsgBox ("用意されていない組み合わせです、ソフト修正が必要です。")
# End If
#
#
# End Function
# Private Function InsideCheck(a1, b1, a2, b2, x, y, InsideJudge)
#
# InsideJudge = False
# If a1 >= 0 And a2 >= 0 Then
#     If y <= a1 * x + b1 Then
#         If y >= a2 * x + b2 Then
#             InsideJudge = True
#         Else
#             InsideJudge = False
#         End If
#     End If
# ElseIf a1 < 0 And a2 >= 0 Then
#     If y >= a1 * x + b1 Then
#         If y >= a2 * x + b2 Then
#             InsideJudge = True
#         Else
#             InsideJudge = False
#         End If
#     End If
# Else
#     MsgBox ("用意されていない組み合わせです、ソフト修正が必要です。")
# End If
#
# End Function
# Private Function AreaCheck(Centx, Centy, x, y, Area)
#
# If x >= Centx Then
#     If y >= Centy Then
#         Area = 1
#     ElseIf y < Centy Then
#         Area = 2
#     End If
# ElseIf x < Centx Then
#     If y >= Centy Then
#         Area = 4
#     ElseIf y < Centy Then
#         Area = 3
#     End If
# End If
#
#
# End Function
#
# Private Function CopyCrossPoint(x, y, Judge, intVertex, ByVal data_no)
#
#     If Judge = True Then
#         intVertex = intVertex + 1
#         Cells(14 + data_no + intVertex, 28) = x: Cells(14 + data_no + intVertex, 29) = y
#     End If
#
# End Function
# Private Function JudgeCrossPoint(Orgx1, Orgy1, Orgx2, Orgy2, Setx1, Sety1, Setx2, Sety2, xTmp, yTmp, Judge)
#
#     Dim OrgxBig As Double, OrgxSmall As Double, OrgyBig As Double, OrgySmall As Double
#     Dim SetxBig As Double, SetxSmall As Double, SetyBig As Double, SetySmall As Double
#
#     If Orgx1 < Orgx2 Then
#         OrgxBig = Orgx2
#         OrgxSmall = Orgx1
#     Else
#         OrgxBig = Orgx1
#         OrgxSmall = Orgx2
#     End If
#
#     If Orgy1 < Orgy2 Then
#         OrgyBig = Orgy2
#         OrgySmall = Orgy1
#     Else
#         OrgyBig = Orgy1
#         OrgySmall = Orgy2
#     End If
#
#     If Setx1 < Setx2 Then
#         SetxBig = Setx2
#         SetxSmall = Setx1
#     Else
#         SetxBig = Setx1
#         SetxSmall = Setx2
#     End If
#
#     If Sety1 < Sety2 Then
#         SetyBig = Sety2
#         SetySmall = Sety1
#     Else
#         SetyBig = Sety1
#         SetySmall = Sety2
#     End If
#
# Judge = False
#
#     If xTmp < OrgxBig And xTmp > OrgxSmall Then
#         If xTmp < SetxBig And xTmp > SetxSmall Then
#             If yTmp < OrgyBig And yTmp > OrgySmall Then
#                 If yTmp < SetyBig And yTmp > SetySmall Then
#                     Judge = True
#                 End If
#             End If
#         End If
#     Else
#         Judge = False
#     End If
#
# End Function
#
# Private Function GetCrossPoint(a1, b1, a2, b2, x, y)
#
# If a1 <> a2 Then
#     x = (b2 - b1) / (a1 - a2)
#     y = a1 * x + b1
# Else
#     x = 0
#     y = 0
# End If
#
# End Function
#
# Private Function makeFormula(x1, y1, x2, y2, a, b)
#
#
# a = (y1 - y2) / (x1 - x2)
# b = y1 - a * x1
#
# End Function
#
#
# Function GetFormula_Right(selrange As Range) As String
#     '式の右辺だけを取り出します
#     'マクロコード作成に便利です
#     '式（＝）がないと「= is not」を返します
#     Dim n%, cellstring$
#
#     cellstring$ = selrange.Formula
#     If Len(cellstring) = 0 Then GoTo isnotequal
#     n = InStr(cellstring, "=")
#
#     If n = 0 Then GoTo isnotequal
#     GetFormula_Right = Right(cellstring, Len(cellstring) - n)
#     Exit Function
# isnotequal:
#     GetFormula_Right = "= is not"
# End Function
# '--------------------------------------------------------------------------------
#
# Function GetFormula_Left(selrange As Range) As String
#     '式の左辺だけを取り出します
#     'マクロコード作成に便利です
#     '式（＝）がないと「= is not」を返します
#     Dim n%, cellstring$
#
#     cellstring = selrange.Formula
#     If Len(cellstring) = 0 Then GoTo isnotequal
#     n = InStr(cellstring, "=")
#
#     If n = 0 Then GoTo isnotequal
#     GetFormula_Left = Left(cellstring, n - 1)
#     Exit Function
# isnotequal:
#     GetFormula_Left = "= is not"
# End Function
# '--------------------------------------------------------------------------------
#
# Function ChangeFormula_RightToLeft(selrange As Range) As String
#     '式の左辺右辺を入れ替えます
#     'マクロコード作成に便利です
#     '式（＝）がないと「= is not」を返します
#     Dim n%, cellstring$
#
#     cellstring = selrange.Formula
#     If Len(cellstring) = 0 Then GoTo isnotequal
#     n = InStr(cellstring, "=")
#
#     If n = 0 Then GoTo isnotequal
#     ChangeFormula_RightToLeft = Right(cellstring, Len(cellstring) - n) _
#         & "=" & Left(cellstring, n - 1)
#     Exit Function
# isnotequal:
# ChangeFormula_RightToLeft = "= is not"
# End Function
# '--------------------------------------------------------------------------------
#
# Function CombineStrings(selrange As Range) As String 'セル文字列を結合
#     '選択範囲のすべての文字列を結合します
#     Dim a As Range
#
#     CombineStrings = ""
#     For Each a In selrange
#         CombineStrings = CombineStrings & a.Formula
#     Next a
# End Function
# '--------------------------------------------------------------------------------
#
# Function Area3Angle_3sd(a, b, C) As Variant
# '三角形の面積
# '３辺の長さから３角形の面積を求めます
#     Dim s
#     'ヘロンの公式により
#     s = (a + b + C) / 2
#     Area3Angle_3sd = Sqr(s * (s - a) * (s - b) * (s - C))
# End Function
# '--------------------------------------------------------------------------------
#
# Function Area3Angle_xy(x1, x2, x3, y1, y2, y3) As Variant
# '三角形の面積
# '３頂点のＸＹ座標から３角形の面積を求めます
#     Area3Angle_xy = (x1 * (y3 - y2) + x2 * (y1 - y3) + x3 * (y2 - y1)) / 2
# End Function
# '--------------------------------------------------------------------------------
#
# Function Area5gon_xy(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5) As Variant
# '五角形の面積xy座標から求めます
# '３角形が３つ合わさったものが５角形
#     Area5gon_xy = Area3Angle_xy(x1, x2, x3, y1, y2, y3) + _
#                 Area3Angle_xy(x1, x3, x4, y1, y3, y4) + _
#                 Area3Angle_xy(x1, x4, x5, y1, y4, y5)
# End Function
# '--------------------------------------------------------------------------------
#
# Function AreaPolygon_xyarray(xyArray) As Variant
# '多角形の面積を求めます
# 'ｎ角形（３角形を含む）の面積を頂点のxy座標の２元配列から求めます
# 'ｘｙ座標が入っているセル範囲、または配列を引数にすることができます
# '縦横どちらでも対応します
# 'xyの順にこだわりません
# '頂点は時計回りでも、その逆でもかまいません
# 'Area3Angle_xyを使って計算しますので、注意してください
# '精度が増すように Variant にしました
#     Dim al, au, bl, bu, array_size, xs(), ys(), n, xy
#     If IsObject(xyArray) Then
#     'セル範囲の場合は、その値を配列に入れる
#         xy = xyArray.Formula
#     ElseIf IsArray(xyArray) Then
#     '配列の場合はそのまま
#         xy = xyArray
#     Else
#         AreaPolygon_xyarray = "エラー!(配列ではありません)"
#         Exit Function
#     End If
#
#     On Error Resume Next
#     '２元配列かどうか調べる
#     al = LBound(xy)
#     au = UBound(xy)
#     bl = LBound(xy, 2)
#     bu = UBound(xy, 2)
#     If Err.Number > 0 Then
#         AreaPolygon_xyarray = "エラー!(適切な配列ではありません)"
#         Exit Function
#     End If
#     If Not (((au - al) = 1) Or ((bu - bl) = 1)) Then
#         AreaPolygon_xyarray = "エラー!(2元配列ではありません)"
#         Exit Function
#     End If
#
#     If (au - al) = 1 Then '縦配列
#         array_size = bu - bl
#         ReDim xs(array_size)
#         ReDim ys(array_size)
#         For n = 0 To bu - bl 'xs,ys配列に置き換え
#             xs(n) = Val(xyArray(al, bl + n))
#             ys(n) = Val(xyArray(au, bl + n))
#         Next n
#     Else '横配列
#         array_size = au - al
#         ReDim xs(array_size)
#         ReDim ys(array_size)
#         For n = 0 To au - al 'xs,ys配列に置き換え
#             xs(n) = Val(xyArray(al + n, bl))
#             ys(n) = Val(xyArray(al + n, bu))
#         Next n
#     End If
#
#     AreaPolygon_xyarray = 0
#     For n = 0 To array_size - 2
#     '３角形が(n-2)合わさったものがn角形
#         AreaPolygon_xyarray = AreaPolygon_xyarray + _
#             Area3Angle_xy(xs(0), xs(n + 1), xs(n + 2), ys(0), ys(n + 1), ys(n + 2))
#     Next n
#
# End Function
# '--------------------------------------------------------------------------------
#
# Function FChooseFrom_a_CSVDataRange(objRange As Range, intIndex As Integer) As Double
# 'intIndexは連続データの入ったセルの値を（例えばB$1形式で）参照するようにしたら楽です。
# 'FGetCsvDatの逆です。例えばA列にCSVデータが複数入り、第1行にB列から1.2...と値を入れたとします。
# 'するとB2のセルは「=Personal.xls!FChooseFrom_a_CSVDataRange($A2,B$1)」
# 'のようになりますか。これを右へフィル、下へフィルするとCSVデータが各セルに展開されます。
#     Dim n%, m%, strCharacter$, strItem$
#     m = 0
#     strItem = ""
#     For n = 1 To Len(objRange.Formula)
#     strCharacter = Mid(objRange.Formula, n, 1)
#     If strCharacter = "," Then 'カンマ区切りのデータです
#         m = m + 1
#         If m = intIndex Then
#             FChooseFrom_a_CSVDataRange = Val(strItem)
#             Exit Function
#         End If
#         strItem = ""
#     Else
#         strItem = strItem + strCharacter
#     End If
#
#     Next n
#     m = m + 1
#     If intIndex = m Then
#         FChooseFrom_a_CSVDataRange = Val(strItem)
#     Else
#         FChooseFrom_a_CSVDataRange = 0 'データがないと0を返します
#     End If
# End Function
# '--------------------------------------------------------------------------------
#
# Function FNumberOfSheets() As Integer
# 'ワークシートの数を返します。シート数が多いときに使えますね。
#     FNumberOfSheets = ActiveWorkbook.Worksheets.Count
#     'ワークシートを挿入したとき、自動再計算してくれないのが難点。
#     'いずれかのセルを編集し直したり（ダブルクリック、enter）、値を入れると再計算します。（少し不便）
# End Function
# '--------------------------------------------------------------------------------
#
# Function FGetDoubleValFromString(文字 As String) As Double
# '文字列の中の数字を集めて小数を返します
#     Dim strCur$, n%, intStrLen%, intCurChr%, strResult$
#     Dim counter%
#
#     strResult = ""
#     counter = 0
#     intStrLen = Len(文字)
#
#     For n = 1 To intStrLen
#         strCur = Mid(文字, n, 1)
#         intCurChr = AscW(strCur)
#         Select Case intCurChr
#             Case 46 '.
#                 'そのまま
#                 counter = counter + 1
#             Case 48 To 57 '半角数字
#                 'そのまま
#                 counter = counter + 1
#             Case -240 To -231 '全角数字
#                 strCur = ChrW(intCurChr + 288)
#                 counter = counter + 1
#             Case 45 '- 頭にだけつける
#                 If counter > 0 Then strCur = ""
#             Case Else '数字以外
#                 strCur = ""
#
#         End Select
#         strResult = strResult & strCur
#     Next n
#     FGetDoubleValFromString = Val(strResult)
# End Function
# '--------------------------------------------------------------------------------
#
# Function FGetLongValFromString(文字 As String) As Long
# '文字列の中の数字を集めて整数を返します
#     Dim strCur$, n%, intStrLen%, intCurChr%, strResult$
#     Dim counter%
#     strResult = ""
#     counter = 0
#     intStrLen = Len(文字)
#
#     For n = 1 To intStrLen
#         strCur = Mid(文字, n, 1)
#         intCurChr = AscW(strCur)
#         Select Case intCurChr
#             Case 48 To 57 '半角数字
#                 'そのまま
#                 counter = counter + 1
#             Case -240 To -231 '全角数字
#                 strCur = ChrW(intCurChr + 288)
#                 counter = counter + 1
#             Case 45 '- 最初だけつける
#                 If counter > 0 Then strCur = ""
#             Case Else '数字以外
#                 strCur = ""
#
#         End Select
#         strResult = strResult & strCur
#     Next n
#     FGetLongValFromString = Val(strResult)
# End Function
# '--------------------------------------------------------------------------------
#
# Function FGetCsvData(選択範囲 As Range) As String
# '選択範囲のセルの値をコンマ区切りのCSVデータ形式にまとめます
#     Dim singlecell As Range
#     Dim strResult$
#
#     strResult = ""
#     For Each singlecell In 選択範囲
#         strResult = strResult & singlecell.Value
#         strResult = strResult & ","
#     Next
#     strResult = Left(strResult, Len(strResult) - 1)
#     FGetCsvData = strResult
# End Function
#
#
# Private Sub CommandButton2_Click()
# Cells(4, 11) = "sRGB"
# Cells(4, 11).Select
#     With Selection.Font
#         .Name = "Arial"
#         .Size = 11
#         .Strikethrough = False
#         .Superscript = False
#         .Subscript = False
#         .OutlineFont = False
#         .Shadow = False
#         .Underline = xlUnderlineStyleNone
#         .ColorIndex = 2
#     End With
#
# Cells(5, 12) = 0.64: Cells(5, 13) = 0.33
# Cells(6, 12) = 0.3: Cells(6, 13) = 0.6
# Cells(7, 12) = 0.15: Cells(7, 13) = 0.06
# Cells(9, 12) = 0.3127: Cells(9, 13) = 0.329
#
#
#
# End Sub
#
# Private Sub CommandButton3_Click()
#
# Cells(4, 11) = "AdobeRGB"
# Cells(4, 11).Select
#     With Selection.Font
#         .Name = "Arial"
#         .Size = 9
#         .Strikethrough = False
#         .Superscript = False
#         .Subscript = False
#         .OutlineFont = False
#         .Shadow = False
#         .Underline = xlUnderlineStyleNone
#         .ColorIndex = 2
#     End With
#
# Cells(5, 12) = 0.64: Cells(5, 13) = 0.33
# Cells(6, 12) = 0.21: Cells(6, 13) = 0.71
# Cells(7, 12) = 0.15: Cells(7, 13) = 0.06
# Cells(9, 12) = 0.3127: Cells(9, 13) = 0.329
#
#
# End Sub
#
# Private Sub CommandButton4_Click()
#
# 'Cells(4, 11) = "NTSC"
# 'Cells(4, 11).Select
#     With Selection.Font
#         .Name = "Arial"
#         .Size = 11
#         .Strikethrough = False
#         .Superscript = False
#         .Subscript = False
#         .OutlineFont = False
#         .Shadow = False
#         .Underline = xlUnderlineStyleNone
#         .ColorIndex = 2
#     End With
#
# Cells(5, 12) = 0.67: Cells(5, 13) = 0.33
# Cells(6, 12) = 0.21: Cells(6, 13) = 0.71
# Cells(7, 12) = 0.14: Cells(7, 13) = 0.08
# Cells(9, 12) = 0.3127: Cells(9, 13) = 0.329
#
# End Sub
#
#
# Private Sub CommandButton5_Click()
#
# Dim i As Integer
# Dim x As Double, y As Double
# Dim u As Double, v As Double
#
# For i = 1 To 15
#     If i = 4 Then
#         i = 5
#     End If
#     If i = 14 Then
#         i = 15
#     End If
#     If i = 6 Then
#         i = 11
#     End If
#     x = Cells(4 + i, 12)
#     y = Cells(4 + i, 13)
#     Call xy2uv(x, y, u, v)
#     Cells(4 + i, 15) = u
#     Cells(4 + i, 16) = v
# Next i
#
# End Sub
#
# Function xy2uv(x, y, u, v)
#
# u = 4 * x / (3 - 2 * x + 12 * y)
# v = 9 * y / (3 - 2 * x + 12 * y)
#
# End Function
#
# Private Sub CommandButton6_Click()
#
# Dim i As Integer
# Dim x As Double, y As Double
# Dim u As Double, v As Double
#
# For i = 1 To 15
#     If i = 4 Then
#         i = 5
#     End If
#     If i = 14 Then
#         i = 15
#     End If
#     If i = 6 Then
#         i = 11
#     End If
#     u = Cells(4 + i, 15)
#     v = Cells(4 + i, 16)
#     Call uv2xy(x, y, u, v)
#     Cells(4 + i, 12) = x
#     Cells(4 + i, 13) = y
# Next i
#
# End Sub
#
# Function uv2xy(x, y, u, v)
#
# x = 9 * u / (2 * (6 + 3 * u - 8 * v))
# y = 2 * v / (6 + 3 * u - 8 * v)
#
# End Function
#
# Private Sub Optuv_Click()
#
# Optxy.Value = False
#
# End Sub
#
# Private Sub Optxy_Click()
#
# Optuv.Value = False
#
# End Sub
# '
# End Sub
#
# Function Get_FilleName(Temp As String, F_name As String)
#
#    Dim RT As Variant
#
#    RT = InStrRev(Temp, "¥")
#
#       If RT > 0 And IsNull(RT) = False Then
#          F_name = Mid(Temp, RT + 1, Len(Temp) - RT - 5) '末尾がxlsの場合は-4
#       Else
#          F_name = ""
#       End If
#
# End Function
#
#
# Sub Button2_Click() 'Button_No2'に以降したため削除可
# '
# '   Application.DisplayAlerts = False
# '
# '    Dim OpenFilename As String, SPE(1) As Object
# '    Dim cnt As String
# '    Dim filename As String
# '    Dim data_no As Integer
# '
# '
# '
# '    OpenFilename = Application.GetOpenFilename("すべてのファイル,*.*")
# '    If OpenFilename <> "False" Then
# '        Workbooks.Open OpenFilename
# '        Set SPE(0) = ActiveWorkbook
# '    Range("B2:D6").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("D15").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '    SPE(0).Worksheets("Sheet2").Activate
# '    Range("B2:F402").Select
# '    Selection.Copy
# '
# '    ThisWorkbook.Worksheets("Spectrum").Activate
# '    Range("B2").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '
# '     Call Get_FilleName(OpenFilename, filename)
# '     ThisWorkbook.Worksheets("Lv_xy").Activate
# '     Range("B13") = filename
# '
# '
# '     SPE(0).Activate
# '     ActiveWindow.Close
# '
# '     data_no = 0
# '
# '     End If
# '
# '     Call calc_area(data_no)
# '
# '     ThisWorkbook.Worksheets("Lv_xy").Activate
# '     Range("A1").Select
# '
# '
# End Function
#
# Sub Button9_Click() 'Button_No2'に移行したため削除可
#
# '     Application.DisplayAlerts = False
# '
# '    Range("AM3:BE10").Select
# '    Selection.Copy
# '    Range("B22").Select
# '    ActiveSheet.Paste
# '
# '    Dim OpenFilename As String, SPE(1) As Object
# '    Dim cnt As String
# '    Dim filename As String
# '    Dim data_no As Integer
# '
# '    OpenFilename = Application.GetOpenFilename("すべてのファイル,*.*")
# '    If OpenFilename <> "False" Then
# '        Workbooks.Open OpenFilename
# '        Set SPE(0) = ActiveWorkbook
# '    Range("B2:D6").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("D24").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '    SPE(0).Worksheets("Sheet2").Activate
# '    Range("B2:F402").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Spectrum").Activate
# '    Range("G2").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '
# '    Call Get_FilleName(OpenFilename, filename)
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Call Get_FilleName(OpenFilename, filename)
# '    Range("B22") = filename
# '
# '    SPE(0).Activate
# '    ActiveWindow.Close
# '
# '    data_no = 9
# '
# '     End If
# '
# '     Call calc_area(data_no)
# '
# '     ThisWorkbook.Worksheets("Lv_xy").Activate
# '     Range("A1").Select
#
#     End Function
#
#
# Sub Button10_Click()  'Button_No3'に移行したため削除可
#
# 'Application.DisplayAlerts = False
# '
# '    Range("AM3:Be10").Select
# '    Selection.Copy
# '    Range("B31").Select
# '    ActiveSheet.Paste
# '
# '    Dim OpenFilename As String, SPE(1) As Object
# '    Dim cnt As String
# '    Dim filename As String
# '    Dim data_no As Integer
# '
# '    OpenFilename = Application.GetOpenFilename("すべてのファイル,*.*")
# '    If OpenFilename <> "False" Then
# '        Workbooks.Open OpenFilename
# '        Set SPE(0) = ActiveWorkbook
# '    Range("B2:D6").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("D33").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '    SPE(0).Worksheets("Sheet2").Activate
# '    Range("B2:F402").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Spectrum").Activate
# '    Range("L2").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '
# '    Call Get_FilleName(OpenFilename, filename)
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("B31") = filename
# '
# '     SPE(0).Activate
# '     ActiveWindow.Close
# '
# '     data_no = 9 * 2
# '
# '     End If
# '
# '     Call calc_area(data_no)
# '
# '     ThisWorkbook.Worksheets("Lv_xy").Activate
# '     Range("A1").Select
#
# End Function
#
# Sub Button11_Click() 'Button_No4'に移行したため削除可
#
# 'Application.DisplayAlerts = False
# '
# '    Range("AM3:Be10").Select
# '    Selection.Copy
# '    Range("B40").Select
# '    ActiveSheet.Paste
# '
# '    Dim OpenFilename As String, SPE(1) As Object
# '    Dim cnt As String
# '    Dim filename As String
# '    Dim data_no As Integer
# '
# '    OpenFilename = Application.GetOpenFilename("すべてのファイル,*.*")
# '    If OpenFilename <> "False" Then
# '        Workbooks.Open OpenFilename
# '        Set SPE(0) = ActiveWorkbook
# '    Range("B2:D6").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("D42").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '    SPE(0).Worksheets("Sheet2").Activate
# '    Range("B2:F402").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Spectrum").Activate
# '    Range("Q2").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '
# '    Call Get_FilleName(OpenFilename, filename)
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '
# '    Range("B40") = filename
# '
# '    SPE(0).Activate
# '    ActiveWindow.Close
# '
# '    data_no = 9 * 3
# '
# '     End If
# '
# '     Call calc_area(data_no)
# '
# '     ThisWorkbook.Worksheets("Lv_xy").Activate
# '     Range("A1").Select
#
# End Function
#
# Sub Button12_Click()  'Button_No5'に移行したため削除可
#
# 'Application.DisplayAlerts = False
# '
# '    Range("AM3:Be10").Select
# '    Selection.Copy
# '    Range("B49").Select
# '    ActiveSheet.Paste
# '
# '    Dim OpenFilename As String, SPE(1) As Object
# '    Dim cnt As String
# '    Dim filename As String
# '    Dim data_no As Integer
# '
# '    OpenFilename = Application.GetOpenFilename("すべてのファイル,*.*")
# '    If OpenFilename <> "False" Then
# '        Workbooks.Open OpenFilename
# '        Set SPE(0) = ActiveWorkbook
# '    Range("B2:D6").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("D51").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '    SPE(0).Worksheets("Sheet2").Activate
# '    Range("B2:F402").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Spectrum").Activate
# '    Range("V2").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '
# '    Call Get_FilleName(OpenFilename, filename)
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("B49") = filename
# '
# '    SPE(0).Activate
# '    ActiveWindow.Close
# '
# '    data_no = 9 * 4
# '
# '    End If
# '
# '    Call calc_area(data_no)
# '
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '     Range("A1").Select
#
# End Function
#
# Sub Button13_Click()  'Button_No6'に移行したため削除可
#
# '    Application.DisplayAlerts = False
# '
# '    Range("AM3:Be10").Select
# '    Selection.Copy
# '    Range("B58").Select
# '    ActiveSheet.Paste
# '
# '    Dim OpenFilename As String, SPE(1) As Object
# '    Dim cnt As String
# '    Dim filename As String
# '    Dim data_no As Integer
# '
# '    OpenFilename = Application.GetOpenFilename("すべてのファイル,*.*")
# '    If OpenFilename <> "False" Then
# '        Workbooks.Open OpenFilename
# '        Set SPE(0) = ActiveWorkbook
# '    Range("B2:D6").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("D60").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '    SPE(0).Worksheets("Sheet2").Activate
# '    Range("B2:F402").Select
# '    Selection.Copy
# '    ThisWorkbook.Worksheets("Spectrum").Activate
# '    Range("AA2").Select
# '    Selection.PasteSpecial Paste:=xlPasteValues, Operation:=xlNone, SkipBlanks _
# '        :=False, Transpose:=False
# '
# '
# '    Call Get_FilleName(OpenFilename, filename)
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '    Range("B58") = filename
# '
# '    SPE(0).Activate
# '    ActiveWindow.Close
# '    data_no = 9 * 5
# '
# '    End If
# '
# '    Call calc_area(data_no)
# '
# '    ThisWorkbook.Worksheets("Lv_xy").Activate
# '     Range("A1").Select
#
# End Function
